# %% [markdown]
# #### Loading Star Catalogs
# Catalogs can be downloaded from a variety of services like VizieR, typically consist of a data file and a ReadMe, explaining its formatting. Below, I will discuss a couple of ways to load these data files and more optimal ways to store them.
#
# We'll start with basic imports, and the `astropy` provided method of loading.

# %%
from astropy.io import ascii
from astropy.table import Table, vstack
import numpy as np
import time
import numpy as np
import pandas as pd

# %%
# Uses Astropy to read the Tycho catalog
### LARGE catalog, and its currently unoptimized, so it will take awhile to load. 
#tycho = ascii.read('./catalog/tyc_main.dat', readme="./catalog/ReadMe")
#print(f"Loaded {len(tycho)} Tycho objects")
#print(tycho.colnames)

# %% [markdown]
# Astropy also provides a method for loading catalog into a table, which is slightly faster and more efficient.

# %%
tycho = Table.read('./catalog/tyc_main.dat', format='ascii', readme="./catalog/ReadMe")

# %% [markdown]
# From a `Table`, we can save it directly to a `.fits` file format, which is **MUCH** faster to load.
# Beforehand, we can remove unncessary columns to also increase speed.

# %%
col_names = ['RAdeg', 'DEdeg', 'TYC', 'Vmag', 'HD']
tycho = tycho[col_names]
tycho.write('./catalog/tyc_main.fits', format='fits', overwrite=True)

# %% [markdown]
# For sky navigation, we'd like some identification for useful, bright stars.
# We will add an extra `Name` column to our fits data file.
# We will use constellation-based names like "33 Psc" as well as coloquial names like Rigel or Polaris.

# %%
tycho = Table.read('./catalog/tyc_main.fits')
common_names = Table.read("./catalog/names.fits")
bright_stars = Table.read('./catalog/catalog', format='ascii', readme="./catalog/ReadMe_bright")
# Out:
# WARNING: VerifyWarning: It is strongly recommended that column names contain only upper and lower-case ASCII letters, digits, or underscores for maximum compatibility with other software (got '---'). [astropy.io.fits.column]
# WARNING: VerifyWarning: It is strongly recommended that column names contain only upper and lower-case ASCII letters, digits, or underscores for maximum compatibility with other software (got '---_1'). [astropy.io.fits.column]
# WARNING: UnitsWarning: '10ms/yr' did not parse as fits unit: Numeric factor not supported by FITS If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: '10mas/yr' did not parse as fits unit: Numeric factor not supported by FITS If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]

# %% [markdown]
# Loop through every entry in Tycho, and look for a name in the other two catalogs by HD number id.

# %%
# create name column in tycho
tycho['Name'] = np.full(len(tycho), '', dtype='U50')
# loop through tycho catalog. look for HD number in common names, then bright stars
for i, row in enumerate(tycho):
    hd_number = row['HD']
    if hd_number == 0:
        continue

    name = ""
    # Check if HD number exists in common names or bright stars
    if hd_number in common_names['HD']:
        common = common_names[common_names['HD'] == hd_number]['name'][0]
        common = str(common).replace('--', '').strip()
        if len(common) > 0:
            name = common
    elif hd_number in bright_stars['HD']:
        bright = bright_stars[bright_stars['HD'] == hd_number]['Name'][0]
        bright = str(bright).replace('--', '').strip()
        if len(bright) > 0:
            name = bright
    tycho['Name'][i] = name
    if len(name) > 0:
        print(f"Found name for HD {hd_number}: {name}")

# Save the updated tycho table with names
tycho.write('./catalog/tyc.fits', format='fits', overwrite=True)
# Found name for HD 7788: Kap Tuc
# Found name for HD 3112: The Tuc
# Found name for HD 14287: Pi 2Hyi
# Found name for HD 14141: Pi 1Hyi
# Found name for HD 17566: Zet Hyi
# Found name for HD 45669: Pi 1Dor
# Found name for HD 33285: Bet Men
# Found name for HD 39810: Lam Men
# Found name for HD 46116: Pi 2Dor
# Found name for HD 55864: Gam1Vol
# Found name for HD 68520: Eps Vol
# Found name for HD 74405: The Vol
# Found name for HD 80007: MIAPLACIDUS
# Found name for HD 71066: Kap2Vol
# Found name for HD 71046: Kap1Vol
# Found name for HD 71576: Eta Vol
# Found name for HD 107566: Zet2Mus
# Found name for HD 107567: Zet1Mus
# Found name for HD 110879: Bet Mus
# Found name for HD 116579: Iot2Mus
# Found name for HD 116244: Iot1Mus
# Found name for HD 141767: Kap TrA
# Found name for HD 138800: Kap2Aps
# Found name for HD 149671: Eta1TrA
# Found name for HD 150798: ATRIA
# Found name for HD 156277: Zet Aps
# Found name for HD 179009: Tau Pav
# Found name for HD 197635: Sig Pav
# Found name for HD 211998: Nu  Ind
# Found name for HD 12363: Sig Hyi
# Found name for HD 11604: Tau2Hyi
# Found name for HD 10859: Tau1Hyi
# Found name for HD 636: Gam3Oct
# Found name for HD 18293: Nu  Hyi
# Found name for HD 29116: Nu  Men
# Found name for HD 38602: Iot Men
# Found name for HD 40953: Kap Men
# Found name for HD 54239: The Men
# Found name for HD 60816: Eps Men
# Found name for HD 85396: Nu  Cha
# Found name for HD 71243: Alp Cha
# Found name for HD 82554: Iot Cha
# Found name for HD 83979: Zet Cha
# Found name for HD 88351: Mu 2Cha
# Found name for HD 87971: Mu 1Cha
# Found name for HD 104902: Kap Cha
# Found name for HD 104174: Eps Cha
# Found name for HD 93779: Del1Cha
# Found name for HD 124771: Eps Aps
# Found name for HD 123998: Eta Aps
# Found name for HD 167468: Phi Oct
# Found name for HD 145388: Del2Aps
# Found name for HD 149324: Bet Aps
# Found name for HD 196067: Mu 2Oct
# Found name for HD 196051: Mu 1Oct
# Found name for HD 210853: Psi Oct
# Found name for HD 215573: Xi  Oct
# Found name for HD 224362: Gam2Oct
# Found name for HD 223647: Gam1Oct
# Found name for HD 130650: Pi 1Oct
# Found name for HD 131246: Pi 2Oct
# Found name for HD 124882: Del Oct
# Found name for HD 131596: Ome Oct
# Found name for HD 206240: Lam Oct
# Found name for HD 206240: Lam Oct
# WARNING: VerifyWarning: It is strongly recommended that column names contain only upper and lower-case ASCII letters, digits, or underscores for maximum compatibility with other software (got '---'). [astropy.io.fits.column]
# WARNING: VerifyWarning: It is strongly recommended that column names contain only upper and lower-case ASCII letters, digits, or underscores for maximum compatibility with other software (got '---_1'). [astropy.io.fits.column]

# %% [markdown]
# Now that our catalog has names, lets remove unnecessary columns so loading and searching is faster.

# %%
tycho = Table.read('./catalog/tyc.fits')
col_names = ['RAdeg', 'DEdeg', 'TYC', 'Vmag', 'Name']
tycho = tycho[col_names]
tycho.write('./catalog/tyc.fits', format='fits', overwrite=True)
# Out:
# WARNING: VerifyWarning: It is strongly recommended that column names contain only upper and lower-case ASCII letters, digits, or underscores for maximum compatibility with other software (got '---'). [astropy.io.fits.column]
# WARNING: VerifyWarning: It is strongly recommended that column names contain only upper and lower-case ASCII letters, digits, or underscores for maximum compatibility with other software (got '---_1'). [astropy.io.fits.column]

# %% [markdown]
# Lets see whats in our catalog now.

# %%
tycho = Table.read('./catalog/tyc.fits')
# get brighest 10 stars
brightest = tycho[np.argsort(tycho['Vmag'])[:100]]
print("Brightest 10 stars:")
for star in brightest:
    print(f"TYC: {star['TYC']}, Vmag: {star['Vmag']}, Name: {star['Name']}")
# Out:
# Brightest 10 stars:
# TYC: 5949  2777 1, Vmag: -1.44, Name: SIRIUS
# TYC: 8534  2277 1, Vmag: -0.63, Name: CANOPUS
# TYC: 9007  5849 1, Vmag: -0.01, Name: RIGEL KENTAURUS
# TYC: 3105  2070 1, Vmag: 0.03, Name: VEGA
# TYC: 3358  3141 1, Vmag: 0.08, Name: CAPELLA
# TYC: 1472  1436 1, Vmag: 0.16, Name: ARCTURUS
# TYC: 5331  1752 1, Vmag: 0.28, Name: RIGEL
# TYC: 187  2184 1, Vmag: 0.4, Name: PROCYON
# TYC: 8478  1395 1, Vmag: 0.54, Name: ACHERNAR
# TYC: 129  1873 1, Vmag: 0.57, Name: BETELGEUSE
# TYC: 9005  3919 1, Vmag: 0.64, Name: --
# TYC: 1058  3399 1, Vmag: 0.93, Name: ALTAIR
# TYC: 1266  1416 1, Vmag: 0.99, Name: ALDEBARAN
# TYC: 5547  1518 1, Vmag: 1.06, Name: SPICA
# TYC: 6803  2158 1, Vmag: 1.07, Name: ANTARES
# TYC: 1920  2194 1, Vmag: 1.22, Name: POLLUX
# TYC: 6977  1267 1, Vmag: 1.23, Name: FOMALHAUT
# TYC: 8979  3464 1, Vmag: 1.28, Name: ACRUX
# TYC: 8659  3107 1, Vmag: 1.31, Name: --
# TYC: 3574  3347 1, Vmag: 1.33, Name: DENEB
# TYC: 9007  5848 1, Vmag: 1.35, Name: Alp2Cen
# TYC: 833  1381 1, Vmag: 1.41, Name: REGULUS
# TYC: 6535  3619 1, Vmag: 1.53, Name: ADHARA
# TYC: 8979  3465 1, Vmag: 1.58, Name: Alp2Cru
# TYC: 7388  1093 1, Vmag: 1.63, Name: SHAULA
# TYC: 8654  3422 1, Vmag: 1.65, Name: GACRUX
# TYC: 113  1856 1, Vmag: 1.66, Name: BELLATRIX
# TYC: 9200  2603 1, Vmag: 1.67, Name: MIAPLACIDUS
# TYC: 1859  1470 1, Vmag: 1.68, Name: ELNATH
# TYC: 4766  2450 1, Vmag: 1.72, Name: ALNILAM
# TYC: 3845  1190 1, Vmag: 1.76, Name: ALIOTH
# TYC: 8438  1959 1, Vmag: 1.77, Name: AL NA'IR
# TYC: 3320  2808 1, Vmag: 1.81, Name: MIRFAK
# TYC: 7401  3471 1, Vmag: 1.81, Name: KAUS AUSTRALIS
# TYC: 8140  6533 1, Vmag: 1.82, Name: --
# TYC: 4146  1274 1, Vmag: 1.82, Name: DUBHE
# TYC: 6532  5001 1, Vmag: 1.84, Name: --
# TYC: 7527  1031 1, Vmag: 2.4, Name: ANKAA
# TYC: 3833  1034 1, Vmag: 2.43, Name: PHECDA
# TYC: 6232  1333 1, Vmag: 2.43, Name: 35Eta Oph
# TYC: 6550  4525 1, Vmag: 2.46, Name: ALUDRA
# TYC: 4252  1870 1, Vmag: 2.47, Name: ALDERAMIN
# TYC: 2243  1831 1, Vmag: 2.47, Name: SCHEAT
# TYC: 8588  4200 1, Vmag: 2.48, Name: --
# TYC: 1711  2475 1, Vmag: 2.49, Name: MARKAB
# TYC: 2695  4139 1, Vmag: 2.49, Name: --
# TYC: 2019  1251 1, Vmag: 2.5, Name: 36Eps Boo
# TYC: 8267  3545 1, Vmag: 2.53, Name: --
# TYC: 58  1618 1, Vmag: 2.55, Name: MENKAR
# TYC: 1439  2479 1, Vmag: 2.56, Name: ZOSMA
# TYC: 8241  3235 1, Vmag: 2.57, Name: --
# TYC: 5632  1042 1, Vmag: 2.58, Name: --
# TYC: 6098  1754 1, Vmag: 2.59, Name: GIENAH

# %% [markdown]
# We are still missing names for some of our brightest stars, lets use another catalog, Hipparcos.
# For every Tycho entry above a threshold brightness and without a HD number, we will look for its TYC ID in Hipparcos to find a correct HD number. We can then research for a name in common names and bright stars.

# %%
tycho = Table.read('./catalog/tyc_main.fits')
hipparcos = Table.read("./catalog/hip_main.dat", format='ascii', readme="./catalog/ReadMe_hip")

col_names = ['RAdeg', 'DEdeg', 'TYC', 'Vmag', 'HD', 'HIP']
tycho = tycho[col_names]

# Filter Vmag < 6.0 and no HD number
#tycho_short = tycho[(tycho['Vmag'] < 6.0) & (tycho['Name'].mask)]

# create name column in tycho short
tycho['Name'] = np.full(len(tycho), '', dtype='U50')
# loop through tycho catalog. look for HD number in common names, then bright stars
for i, row in enumerate(tycho):
    name = ""
    hd_number = row['HD']
    mag = row['Vmag']
    if mag > 8.0:
        continue
    if not isinstance(hd_number, np.int64):
        hip_number = row['HIP']

        hip = hipparcos[hipparcos['HIP'] == hip_number]
        if len(hip) == 0:
            continue
        else:
            hd_number = hip['HD'][0]
    
    if hd_number in common_names['HD']:
            common = common_names[common_names['HD'] == hd_number]['name'][0]
            common = str(common).replace('--', '').strip()
            if len(common) > 0:
                name = common
    elif hd_number in bright_stars['HD']:
        bright = bright_stars[bright_stars['HD'] == hd_number]['Name'][0]
        bright = str(bright).replace('--', '').strip()
        if len(bright) > 0:
            name = bright

    
    tycho['Name'][i] = name
    if len(name) > 0:
        print(f"Found{name}")

col_names = ['RAdeg', 'DEdeg', 'TYC', 'Vmag', 'Name']
tycho = tycho[col_names]
tycho.write('./catalog/tyc.fits', format='fits', overwrite=True)
# Out:
# WARNING: VerifyWarning: It is strongly recommended that column names contain only upper and lower-case ASCII letters, digits, or underscores for maximum compatibility with other software (got '---'). [astropy.io.fits.column]
# WARNING: VerifyWarning: It is strongly recommended that column names contain only upper and lower-case ASCII letters, digits, or underscores for maximum compatibility with other software (got '---_1'). [astropy.io.fits.column]
# Found51    Psc
# Found60    Psc
# Found96 G  PSC
# Found62    Psc
# Found33    Cet
# Found77    Psc
# Found77    Psc
# Found73    Psc
# Found80    Psc
# Found88    Psc
# Found98Mu  Psc
# Found60    Cet
# Found69    Cet
# Found112    Psc
# Found113Alp Psc
# Found113Alp Psc
# Found86Gam Cet
# Found86Gam Cet
# Found268 G CET
# Found93    Cet
# FoundMENKAR
# Found97Kap2Cet
# Found12    Tau
# Found31    Tau
# Found40    Tau
# Found45    Tau
# Found10Pi 6Ori
# Found5    Ori
# Found25Psi1Ori
# Found17Rho Ori
# Found21    Ori
# Found23    Ori
# Found30Psi2Ori
# Found30Psi2Ori
# FoundBELLATRIX
# Found51    Ori
# Found56    Ori
# Found59    Ori
# Found33    Ori
# Found33    Ori
# Found38    Ori
# Found47Ome Ori
# Found32    Ori
# Found52    Ori
# FoundBETELGEUSE
# Found63    Ori
# Found12    Mon
# Found5Eta CMi
# Found9Del3CMi
# Found7Del1CMi
# Found8Del2CMi
# Found14    CMi
# FoundPROCYON
# Found7Eta Hya
# Found10    Hya
# Found11Eps Hya
# Found11Eps Hya
# Found13Rho Hya
# Found18Ome Hya
# Found7    Sex
# Found4    Sex
# Found10    Leo
# FoundRS SEX
# Found13    Sex
# Found19    Sex
# Found14    Sex
# Found43    Leo
# Found36    Sex
# Found55    Leo
# Found55    Leo
# Found35    Sex
# Found35    Sex
# Found48    Leo
# Found56    Leo
# Found75    Leo
# Found76    Leo
# Found79    Leo
# Found80    Leo
# Found59    Leo
# FoundZAVIJAVA
# Found89    Leo
# Found7    Vir
# Found10    Vir
# Found11    Vir
# Found17    Vir
# Found37    Vir
# Found31    Vir
# Found64    Vir
# Found92    Vir
# Found84    Vir
# Found84    Vir
# Found108    Vir
# Found5    Ser
# Found6    Ser
# Found4    Ser
# Found10    Ser
# Found110    Vir
# Found23Psi Ser
# Found34Ome Ser
# FoundUNUKALHAI
# Found27Lam Ser
# Found43    Ser
# Found9    Her
# Found14    Oph
# Found21    Oph
# Found16    Oph
# Found10Lam Oph
# Found10Lam Oph
# Found28    Her
# Found37    Her
# Found36    Her
# Found45    Her
# Found47    Her
# FoundU OPH
# Found61    Oph
# FoundCEBALRAI
# Found68    Oph
# Found59    Ser
# Found59    Ser
# Found70    Oph
# Found70    Oph
# Found66    Oph
# Found73    Oph
# Found4    Aql
# Found64    Ser
# FoundALYA
# Found63The2Ser
# Found24    Aql
# Found23    Aql
# Found32Nu  Aql
# Found21    Aql
# Found35    Aql
# Found22    Aql
# Found19    Aql
# Found58    Aql
# Found44Sig Aql
# FoundALSHAIN
# Found1    Aqr
# Found1Eps Equ
# Found13    Del
# Found13    Del
# Found3    Equ
# FoundKITALPHA
# Found4    Equ
# Found9    Equ
# Found10Bet Equ
# Found26    Aqr
# Found25    Aqr
# Found3    Peg
# Found3    Peg
# Found4    Peg
# Found7    Peg
# Found28    Aqr
# Found37    Peg
# Found34    Peg
# Found35    Peg
# Found18    Peg
# Found22Nu  Peg
# FoundBIHAM
# Found30    Peg
# Found1    Psc
# Found2    Psc
# Found5    Psc
# Found3    Psc
# Found9    Psc
# Found7    Psc
# Found16    Psc
# Found21    Psc
# Found25    Psc
# Found19    Psc
# Found22    Psc
# Found26    Psc
# Found32    Psc
# Found31    Psc
# Found35    Psc
# Found36    Psc
# Found34    Psc
# Found86    Peg
# Found42    Psc
# Found58    Psc
# Found86Zet Psc
# Found75    Psc
# Found101    Psc
# Found64    Cet
# Found24Xi  Ari
# Found31    Ari
# Found38    Ari
# Found6    Tau
# Found4    Tau
# Found30    Tau
# Found46    Tau
# Found47    Tau
# Found47    Tau
# Found66    Tau
# Found88    Tau
# Found79    Tau
# Found57    Tau
# Found73Pi  Tau
# Found60    Tau
# Found76    Tau
# Found83    Tau
# Found2Pi 2Ori
# Found7Pi 1Ori
# Found90    Tau
# Found93    Tau
# Found6    Ori
# Found9Omi2Ori
# Found14    Ori
# Found40Phi2Ori
# Found13    Ori
# Found39Lam Ori
# Found39Lam Ori
# Found18    Ori
# Found35    Ori
# Found61Mu  Ori
# Found134    Tau
# Found131    Tau
# Found135    Tau
# Found133    Tau
# Found137    Tau
# Found14    Mon
# Found75    Ori
# Found73    Ori
# Found70Xi  Ori
# Found17    Mon
# Found15    Mon
# Found15    Mon
# Found32    Gem
# Found30    Gem
# Found35    Gem
# Found38    Gem
# Found38    Gem
# Found2Eps CMi
# Found4Gam CMi
# FoundGOMEISA
# Found1    CMi
# Found8    Cnc
# Found12    Cnc
# Found21    Cnc
# Found21    Cnc
# Found34    Cnc
# Found37    Cnc
# Found36    Cnc
# Found27    Cnc
# Found50    Cnc
# Found49    Cnc
# Found60    Cnc
# FoundACUBENS
# Found45    Cnc
# Found2Ome Leo
# Found3    Leo
# Found6    Leo
# Found81Pi 1Cnc
# Found82Pi 2Cnc
# Found7    Leo
# Found31    Leo
# Found18    Leo
# Found19    Leo
# Found27Nu  Leo
# FoundREGULUS
# Found23    Leo
# Found34    Leo
# Found45    Leo
# Found44    Leo
# Found49    Leo
# Found49    Leo
# Found37    Leo
# Found42    Leo
# Found52    Leo
# Found1Ome Vir
# Found78Iot Leo
# Found78Iot Leo
# Found73    Leo
# Found88    Leo
# Found2Xi  Vir
# Found4    Vir
# Found6    Vir
# Found12    Vir
# FoundDENEBOLA
# Found20    Vir
# Found27    Vir
# Found6    Com
# Found33    Vir
# Found41    Vir
# Found34    Vir
# FoundVINDEMIATRIX
# Found29    Com
# Found28    Com
# Found59    Vir
# Found71    Vir
# Found15    Boo
# Found15    Boo
# Found14    Boo
# Found31    Boo
# Found30Zet Boo
# Found13Del Ser
# Found13Del Ser
# Found16    Ser
# Found7    Ser
# Found20Chi Ser
# Found31Ups Ser
# Found40    Ser
# Found47    Ser
# Found45    Ser
# Found39    Ser
# FoundPhi Ser
# Found43    Her
# Found29    Her
# Found37    Oph
# Found64Alp1Her
# Found64Alp2Her
# Found53    Oph
# FoundRASALHAGUE
# Found71    Oph
# Found18    Aql
# Found29Ome2Aql
# Found28    Aql
# Found10    Aql
# Found11    Aql
# Found49Ups Aql
# FoundALTAIR
# Found59Xi  Aql
# FoundTARAZED
# Found54Omi Aql
# Found46    Aql
# Found47Chi Aql
# Found52Pi  Aql
# Found52Pi  Aql
# Found48Psi Aql
# Found61Phi Aql
# Found14    Del
# Found1    Del
# Found3Eta Del
# Found5Iot Del
# Found16    Del
# Found15    Del
# Found4Zet Del
# Found6Bet Del
# Found8The Del
# Found10    Del
# Found17    Del
# Found18    Del
# Found6    Equ
# Found7Del Equ
# FoundENIF
# Found17    Peg
# Found19    Peg
# Found21    Peg
# Found49Sig Peg
# Found50Rho Peg
# Found46Xi  Peg
# FoundHOMAM
# Found58    Peg
# Found57    Peg
# Found52    Peg
# Found66    Peg
# Found80    Peg
# Found77    Peg
# FoundALGENIB
# Found87    Peg
# Found47    Psc
# Found53    Psc
# Found57    Psc
# Found59    Psc
# Found66    Psc
# Found55    Psc
# Found52    Psc
# Found54    Psc
# Found61    Psc
# Found87    Psc
# Found81Psi3Psc
# Found93Rho Psc
# Found97    Psc
# Found74Psi1Psc
# Found74Psi1Psc
# Found79Psi2Psc
# Found105    Psc
# Found5Gam2Ari
# Found5Gam2Ari
# Found8Iot Ari
# Found109    Psc
# Found107    Psc
# Found1    Ari
# Found1    Ari
# FoundSHERATAN
# Found29    Ari
# Found26    Ari
# Found17Eta Ari
# Found37Omi Ari
# Found42Pi  Ari
# Found42Pi  Ari
# Found40    Ari
# Found36    Ari
# Found45Rho2Ari
# Found46Rho3Ari
# Found54    Ari
# Found53    Ari
# Found34Mu  Ari
# Found48Eps Ari
# Found14    Tau
# Found13    Tau
# Found65    Ari
# Found63Tau2Ari
# Found48    Tau
# Found32    Tau
# Found39    Tau
# Found63    Tau
# Found58    Tau
# Found75    Tau
# Found77The1Tau
# Found70    Tau
# Found78The2Tau
# Found85    Tau
# Found81    Tau
# Found80    Tau
# Found80    Tau
# Found71    Tau
# FoundALDEBARAN
# Found89    Tau
# Found92Sig2Tau
# Found91Sig1Tau
# Found64Del2Tau
# Found68Del3Tau
# Found68Del3Tau
# Found50Ome2Tau
# Found56    Tau
# Found51    Tau
# Found53    Tau
# Found65Kap1Tau
# Found67Kap2Tau
# Found96    Tau
# Found15    Ori
# Found104    Tau
# Found106    Tau
# Found105    Tau
# Found108    Tau
# Found109    Tau
# Found110    Tau
# Found113    Tau
# Found116    Tau
# Found126    Tau
# Found129    Tau
# Found111    Tau
# Found119    Tau
# Found120    Tau
# Found117    Tau
# Found122    Tau
# Found114    Tau
# Found72    Ori
# Found69    Ori
# Found57    Ori
# Found54Chi1Ori
# Found62Chi2Ori
# Found64    Ori
# Found68    Ori
# Found71    Ori
# Found19    Gem
# FoundALHENA
# Found33    Gem
# Found26    Gem
# Found16    Gem
# Found36    Gem
# Found41    Gem
# Found45    Gem
# FoundBQ GEM
# Found61    Gem
# Found56    Gem
# FoundWASAT
# Found63    Gem
# Found63    Gem
# Found68    Gem
# Found74    Gem
# Found79    Gem
# Found85    Gem
# Found5    Cnc
# Found3    Cnc
# Found16Zet2Cnc
# Found16Zet2Cnc
# Found16Zet2Cnc
# Found25    Cnc
# Found31The Cnc
# Found10Mu 2Cnc
# Found54    Cnc
# Found63Omi2Cnc
# Found62Omi1Cnc
# Found35    Cnc
# Found41Eps Cnc
# FoundASELLUS AUSTRALIS
# Found39    Cnc
# FoundASELLUS BOREALIS
# Found79    Cnc
# Found8    Leo
# Found20    Leo
# Found41Gam1Leo
# Found41Gam1Leo
# Found40    Leo
# Found60    Leo
# Found81    Leo
# FoundCHERTAN
# Found86    Leo
# Found90    Leo
# Found90    Leo
# Found85    Leo
# FoundZOSMA
# Found92    Leo
# Found2    Com
# Found2    Com
# Found5    Com
# Found11    Com
# Found24    Com
# Found25    Com
# Found27    Com
# Found26    Com
# Found38    Com
# Found36    Com
# Found42Alp Com
# Found35    Com
# Found5Ups Boo
# Found1    Boo
# Found1    Boo
# Found2    Boo
# Found6    Boo
# Found20    Boo
# Found7    Boo
# FoundMUPHRID
# FoundARCTURUS
# Found10    Boo
# Found35Omi Boo
# Found29Pi 1Boo
# Found29Pi 2Boo
# Found37Xi  Boo
# Found37Xi  Boo
# Found26    Boo
# Found18Tau5Ser
# Found12Tau2Ser
# Found26Tau8Ser
# Found19Tau6Ser
# Found15Tau3Ser
# Found21Iot Ser
# Found22Tau7Ser
# Found38Rho Ser
# Found5    Her
# Found8    Her
# Found7Kap Her
# Found16    Her
# FoundKORNEPHOROS
# Found54    Her
# Found98    Her
# Found95    Her
# Found95    Her
# Found96    Her
# Found101    Her
# Found102    Her
# Found106    Her
# Found112    Her
# Found4Eps Sge
# Found2    Sge
# Found5Alp Sge
# Found5    Vul
# Found4    Vul
# Found7    Vul
# Found9    Vul
# Found1    Vul
# Found1    Sge
# Found10    Sge
# Found11    Sge
# Found9    Sge
# Found15    Sge
# Found13    Sge
# Found8Zet Sge
# Found16Eta Sge
# Found17The Sge
# Found12Gam1Del
# Found18    Sge
# Found9    Peg
# Found13    Peg
# Found25    Peg
# Found28    Peg
# Found33    Peg
# Found41    Peg
# Found39    Peg
# Found40    Peg
# FoundMARKAB
# Found51    Peg
# Found65    Peg
# Found74    Peg
# Found75    Peg
# Found71    Peg
# Found85    Peg
# FoundALPHERATZ
# Found28    And
# Found36    And
# Found38Eta And
# Found67    Psc
# Found65    Psc
# Found65    Psc
# Found85Phi Psc
# Found91    Psc
# Found9Lam Ari
# Found7    Ari
# FoundHAMAL
# Found12Kap Ari
# Found14    Ari
# Found16    Ari
# Found10    Ari
# Found11    Ari
# Found20    Ari
# Found30    Ari
# Found30    Ari
# Found33    Ari
# Found10    Tri
# Found13    Tri
# Found52    Ari
# Found60    Ari
# Found49    Ari
# Found56    Ari
# Found59    Ari
# Found39    Ari
# Found66    Ari
# Found20    Tau
# Found16    Tau
# FoundELECTRA
# Found28    Tau
# FoundALCYONE
# FoundATLAS
# Found23    Tau
# Found64    Ari
# Found7    Tau
# Found18    Tau
# Found21    Tau
# Found19    Tau
# Found22    Tau
# Found62    Ari
# Found33    Tau
# Found36    Tau
# Found62    Tau
# Found72    Tau
# Found69Ups Tau
# Found59Chi Tau
# Found41    Tau
# Found52Phi Tau
# Found42Psi Tau
# Found95    Tau
# Found99    Tau
# Found98    Tau
# Found103    Tau
# Found118    Tau
# Found118    Tau
# Found22    Aur
# FoundELNATH
# Found121    Tau
# Found125    Tau
# Found132    Tau
# Found132    Tau
# Found139    Tau
# Found7Eta Gem
# Found7Eta Gem
# Found8    Gem
# Found3    Gem
# Found6    Gem
# Found9    Gem
# Found5    Gem
# Found49    Aur
# Found53    Aur
# Found54    Aur
# Found25    Gem
# Found44    Gem
# Found48    Gem
# FoundMEBSUTA
# Found37    Gem
# Found40    Gem
# Found39    Gem
# Found52    Gem
# Found47    Gem
# Found28    Gem
# Found58    Gem
# Found82    Gem
# Found57    Gem
# Found76    Gem
# Found53    Gem
# Found64    Gem
# Found65    Gem
# Found59    Gem
# FoundPOLLUX
# Found75Sig Gem
# Found9Mu 1Cnc
# Found19Lam Cnc
# Found4Ome2Cnc
# Found14Psi Cnc
# Found15    Cnc
# Found24    Cnc
# Found24    Cnc
# Found32Ups2Cnc
# Found28    Cnc
# Found30Ups1Cnc
# Found23Phi2Cnc
# Found23Phi2Cnc
# Found22Phi1Cnc
# Found48Iot Cnc
# Found55Rho1Cnc
# Found53    Cnc
# Found58Rho2Cnc
# Found69Nu  Cnc
# Found75    Cnc
# Found67    Cnc
# Found70    Cnc
# Found72Tau Cnc
# Found4Lam Leo
# Found22    Leo
# Found13    Leo
# FoundRASALAS
# Found35    Leo
# FoundADHAFERA
# Found39    Leo
# Found24    LMi
# Found23    LMi
# Found48    LMi
# Found50    LMi
# Found64    Leo
# Found54    Leo
# Found54    Leo
# Found67    Leo
# Found43    LMi
# Found44    LMi
# Found40    LMi
# Found72    Leo
# Found4    Com
# Found7    Com
# Found13    Com
# Found17    Com
# Found21    Com
# Found18    Com
# Found8    Com
# Found22    Com
# Found15Gam Com
# Found9    Com
# Found14    Com
# Found16    Com
# Found30    Com
# Found40    Com
# Found41    Com
# Found9    Boo
# Found36Eps Boo
# Found36Eps Boo
# FoundW BOOTES
# Found41Ome Boo
# Found46    Boo
# FoundALPHECCA
# Found48Chi Boo
# Found1Omi CrB
# FoundNUSAKAN
# Found44Pi  Ser
# Found8Gam CrB
# Found10Del CrB
# Found14Iot CrB
# Found10    Her
# Found39    Her
# Found18Ups CrB
# Found63    Her
# Found57    Her
# Found56    Her
# Found50    Her
# Found73    Her
# Found79    Her
# Found84    Her
# Found70    Her
# Found83    Her
# Found87    Her
# Found78    Her
# Found97    Her
# Found100    Her
# Found100    Her
# Found105    Her
# Found108    Her
# Found107    Her
# Found113    Her
# Found2    Vul
# Found2    Vul
# Found8    Vul
# Found3    Vul
# Found6Bet2Cyg
# FoundALBIREO
# Found2    Cyg
# Found13    Vul
# Found13    Vul
# Found12    Vul
# Found14    Vul
# Found16    Vul
# Found9    Cyg
# Found17    Vul
# Found22    Vul
# Found28    Vul
# Found25    Vul
# Found26    Vul
# Found18    Vul
# Found19    Vul
# Found20    Vul
# Found23    Vul
# Found27    Vul
# Found21    Vul
# Found30    Vul
# Found31    Vul
# Found10Kap Peg
# Found35    Vul
# Found78Mu 1Cyg
# Found78Mu 1Cyg
# Found12    Peg
# Found15    Peg
# Found23    Peg
# FoundSADALBARI
# Found32    Peg
# Found43Omi Peg
# Found56    Peg
# FoundSCHEAT
# Found60    Peg
# Found61    Peg
# Found69    Peg
# Found78    Peg
# Found79    Peg
# Found69Sig Psc
# Found82    Psc
# Found78    Psc
# FoundMIRACH
# Found5    Tri
# Found6    Tri
# Found6    Tri
# Found3Eps Tri
# Found7    Tri
# Found8Del Tri
# Found56    And
# Found11    Tri
# Found21    Per
# Found15    Tri
# Found17    Per
# Found38Omi Per
# Found38Omi Per
# Found42    Per
# FoundATIK
# Found40    Per
# FoundMENKIB
# Found55    Per
# Found56    Per
# Found16    Aur
# Found14    Aur
# Found18    Aur
# Found17    Aur
# Found19    Aur
# Found2    Aur
# Found26    Aur
# Found24Phi Aur
# Found21Sig Aur
# Found31Ups Aur
# Found37The Aur
# Found48    Aur
# Found46Tau Gem
# Found66Alp Gem
# Found66Alp Gem
# Found70    Gem
# Found71Omi Gem
# Found65    Aur
# Found46    Cnc
# Found51Sig1Cnc
# Found57    Cnc
# Found61    Cnc
# Found59Sig2Cnc
# Found32    Lyn
# Found33    Lyn
# Found66    Cnc
# Found7    LMi
# Found38    Lyn
# Found38    Lyn
# Found9    LMi
# Found11    LMi
# Found8    LMi
# Found13    LMi
# Found21    LMi
# Found22    LMi
# Found33    LMi
# Found28    LMi
# Found30    LMi
# Found34    LMi
# Found35    LMi
# Found46    UMa
# FoundALULA BOREALIS
# Found62    UMa
# Found37    Com
# Found25    CVn
# Found25    CVn
# Found2Eta CrB
# Found50    Boo
# Found51Mu 2Boo
# Found51Mu 2Boo
# FoundALKALUROPS
# Found9Pi  CrB
# Found15Rho CrB
# Found7Zet1CrB
# Found7Zet2CrB
# Found19Xi  CrB
# Found40Zet Her
# Found40Zet Her
# Found17Sig CrB
# Found17Sig CrB
# Found20Nu 1CrB
# Found21Nu 2CrB
# Found25    Her
# Found68    Her
# Found61    Her
# Found69    Her
# Found75Rho Her
# Found75Rho Her
# Found94Nu  Her
# Found99    Her
# Found104    Her
# Found19    Lyr
# FoundSHELIAK
# Found8Nu 1Lyr
# Found9Nu 2Lyr
# FoundSULAFAT
# Found15Lam Lyr
# Found17    Lyr
# Found11Del1Lyr
# Found12Del2Lyr
# Found12Phi Cyg
# Found17    Cyg
# Found4    Cyg
# Found11    Cyg
# FoundChi Cyg
# Found39    Cyg
# Found35    Cyg
# Found25    Cyg
# Found29    Cyg
# Found27    Cyg
# Found36    Cyg
# Found48    Cyg
# Found52    Cyg
# Found49    Cyg
# Found49    Cyg
# Found47    Cyg
# Found44    Cyg
# Found54Lam Cyg
# Found69    Cyg
# Found70    Cyg
# FoundMATAR
# Found64    Peg
# Found63    Peg
# Found72    Peg
# Found73    Peg
# Found24The And
# Found23    And
# Found26    And
# Found45    And
# Found32    And
# Found39    And
# Found44    And
# Found41    And
# Found47    And
# Found53Tau And
# Found55    And
# Found52Chi And
# Found58    And
# Found59    And
# Found59    And
# FoundALMACH
# FoundALMACH
# Found60    And
# Found20    Per
# Found16    Per
# Found12    Per
# Found22Pi  Per
# FoundALGOL
# Found28Ome Per
# Found27Kap Per
# Found30    Per
# Found32    Per
# Found49    Per
# Found50    Per
# Found52    Per
# Found58    Per
# Found4Ome Aur
# Found5    Aur
# Found5    Aur
# Found6    Aur
# Found59    Per
# Found29Tau Aur
# Found20Rho Aur
# FoundMENKALINAN
# Found40    Aur
# Found52Psi3Aur
# Found39    Aur
# Found38    Aur
# Found50Psi2Aur
# Found61Psi8Aur
# Found59    Aur
# Found60    Aur
# Found62    Aur
# Found58Psi7Aur
# Found55Psi4Aur
# Found28    Lyn
# Found35    Lyn
# Found43    Lyn
# Found42    Lyn
# Found32    LMi
# Found38    LMi
# FoundTANIA AUSTRALIS
# FoundTANIA BOREALIS
# Found49    UMa
# Found51    UMa
# Found45Ome UMa
# Found57    UMa
# FoundGROOMBRIDGE 1830
# Found59    UMa
# Found56    UMa
# Found9    CVn
# Found67    UMa
# Found4    CVn
# FoundCHARA
# Found10    CVn
# FoundCOR CAROLI
# Found12Alp1CVn
# Found19    CVn
# Found15    CVn
# Found15    CVn
# FoundSEGINUS
# Found40    Boo
# FoundNEKKAR
# Found6Mu  CrB
# Found12Lam CrB
# Found53Nu 2Boo
# Found2    Her
# Found4    Her
# Found30    Her
# Found90    Her
# Found90    Her
# FoundVEGA
# Found2Mu  Lyr
# Found6Zet1Lyr
# Found7Zet2Lyr
# Found20Eta Lyr
# Found4Eps1Lyr
# Found4Eps1Lyr
# Found5Eps2Lyr
# Found5Eps2Lyr
# FoundR LYRAE
# Found19    Cyg
# Found22    Cyg
# Found14    Cyg
# Found34    Cyg
# Found40    Cyg
# FoundSADR
# Found61    Cyg
# Found65Tau Cyg
# Found56    Cyg
# Found57    Cyg
# Found68    Cyg
# Found72    Cyg
# Found79    Cyg
# Found76    Cyg
# Found77    Cyg
# Found75    Cyg
# Found1    Lac
# Found8    Lac
# Found6    Lac
# Found12    Lac
# Found14    Lac
# Found16    Lac
# Found2    And
# Found10    And
# Found9    And
# Found11    Lac
# Found15    Lac
# Found6    And
# Found14    And
# Found13    And
# Found20Pi  Cas
# Found19Xi  Cas
# Found42Phi And
# Found25Nu  Cas
# Found49    And
# Found3    Per
# Found63    And
# Found65    And
# Found64    And
# Found66    And
# Found36    Per
# Found37Psi Per
# Found29    Per
# Found31    Per
# FoundMIRFAK
# Found34    Per
# Found53    Per
# Found43    Per
# Found9    Aur
# FoundCAPELLA
# Found35Pi  Aur
# Found43    Aur
# Found42    Aur
# Found47    Aur
# Found36    Aur
# Found41    Aur
# Found41    Aur
# FoundPsi9Aur
# Found16    Lyn
# Found22    Lyn
# Found21    Lyn
# Found25    Lyn
# FoundTALITHA
# Found15    UMa
# Found26    UMa
# Found31    UMa
# Found65    UMa
# Found60    UMa
# Found65    UMa
# Found5    CVn
# Found7    CVn
# Found11    CVn
# FoundY CVN
# Found21    CVn
# Found24    CVn
# FoundALKAID
# Found13    Boo
# Found17Kap2Boo
# Found17Kap1Boo
# Found38    Boo
# Found24    Boo
# Found39    Boo
# Found39    Boo
# Found44    Boo
# Found44    Boo
# Found6Ups Her
# Found52    Her
# Found52    Her
# Found34    Her
# Found74    Her
# Found82    Her
# Found88    Her
# FoundRASTABAN
# FoundELTANIN
# Found30    Dra
# Found16    Lyr
# Found7Iot1Cyg
# Found18Del Cyg
# Found18Del Cyg
# Found30    Cyg
# FoundV695 CYG
# Found16    Cyg
# Found26    Cyg
# Found24Psi Cyg
# Found24Psi Cyg
# FoundDENEB
# Found55    Cyg
# Found32    Cyg
# FoundV832 CYG
# Found43    Cyg
# Found46Ome2Cyg
# Found45Ome1Cyg
# Found51    Cyg
# Found60    Cyg
# Found60    Cyg
# Found63    Cyg
# Found80Pi 1Cyg
# Found2    Lac
# Found5    Lac
# Found4    Lac
# Found4    And
# Found3    And
# Found7    And
# Found9    Lac
# Found11    And
# Found8    And
# Found18    And
# Found14Lam Cas
# FoundSCHEDAR
# Found24Eta Cas
# Found24Eta Cas
# FoundCAPH
# Found33The Cas
# Found28Ups2Cas
# Found26Ups1Cas
# Found34Phi Cas
# Found39Chi Cas
# Found1    Per
# Found9    Per
# Found5    Per
# Found10    Per
# Found7    Per
# Found8    Per
# Found11    Per
# Found3    Cam
# Found2    Cam
# Found7    Cam
# Found8    Cam
# Found5    Cam
# Found15    Cam
# Found12    Cam
# Found11    Cam
# Found26    Cam
# Found16    Cam
# Found24    Cam
# Found29    Cam
# Found31    Cam
# Found30    Cam
# Found37    Cam
# Found45    Aur
# Found7    Lyn
# Found11    Lyn
# Found13    Lyn
# Found4    Lyn
# Found40    Cam
# Found5    Lyn
# Found6    Lyn
# Found14    Lyn
# Found12    Lyn
# Found12    Lyn
# Found12    Lyn
# Found15    Lyn
# Found19    Lyn
# Found23    Lyn
# Found18    Lyn
# Found47    Cam
# Found47    Cam
# Found29    Lyn
# Found30    Lyn
# Found18    UMa
# Found17    UMa
# Found30Phi UMa
# Found44    UMa
# Found43    UMa
# Found41    UMa
# Found39    UMa
# FoundMERAK
# Found42    UMa
# FoundPHECDA
# Found66    UMa
# Found68    UMa
# FoundMEGREZ
# Found71    UMa
# Found70    UMa
# Found73    UMa
# Found78    UMa
# Found78    UMa
# FoundALIOTH
# Found75    UMa
# Found80    UMa
# FoundMIZAR
# Found79Zet UMa
# Found82    UMa
# Found83    UMa
# Found84    UMa
# Found86    UMa
# Found81    UMa
# FoundEDASICH
# Found17    Dra
# Found17    Dra
# Found16    Dra
# Found21Mu  Dra
# Found21Mu  Dra
# FoundGRUMIUM
# Found45    Dra
# Found39    Dra
# Found51    Dra
# Found46    Dra
# Found49    Dra
# Found48    Dra
# Found53    Dra
# Found54    Dra
# Found20    Cyg
# Found23    Cyg
# Found13    Cep
# Found14    Cep
# FoundMu  Cep
# Found22Lam Cep
# Found23Eps Cep
# Found1    Cas
# Found8Sig Cas
# Found8Sig Cas
# FoundBRADLEY 3077
# Found2    Cas
# Found5Tau Cas
# Found12    Cas
# Found9    Cas
# Found10    Cas
# Found13    Cas
# Found16    Cas
# FoundRUCHBAH
# Found44    Cas
# Found35    Cas
# Found32    Cas
# Found52    Cas
# Found53    Cas
# FoundIot Cas
# FoundIot Cas
# Found14    Cam
# Found19    Cam
# Found19    Cam
# Found23    Cam
# Found1    Lyn
# Found49    Cam
# Found51    Cam
# FoundMUSCIDA
# Found5    UMa
# Found4Pi 2UMa
# Found6    UMa
# Found2    UMa
# Found3Pi 1UMa
# Found11Sig1UMa
# Found16    UMa
# Found14Tau UMa
# Found28    UMa
# Found13Sig2UMa
# Found13Sig2UMa
# FoundDUBHE
# Found35    UMa
# Found38    UMa
# Found7    Dra
# Found9    Dra
# FoundTHUBAN
# FoundRR UMI
# Found14Eta Dra
# Found18    Dra
# Found20    Dra
# Found19    Dra
# Found26    Dra
# Found26    Dra
# Found42    Dra
# Found55    Dra
# Found58Pi  Dra
# Found68    Dra
# Found66    Dra
# Found71    Dra
# Found65    Dra
# Found64    Dra
# FoundALDERAMIN
# Found9    Cep
# Found6    Cep
# Found4    Cep
# Found7    Cep
# Found12    Cep
# Found18    Cep
# Found19    Cep
# Found25    Cep
# Found17Xi  Cep
# Found17Xi  Cep
# Found26    Cep
# Found6    Cas
# Found6    Cas
# Found31    Cas
# Found23    Cas
# Found46Ome Cas
# Found42    Cas
# Found48    Cas
# Found42    Cam
# Found22    UMa
# Found27    UMa
# Found2    Dra
# FoundGIAUSAR
# Found4    Dra
# Found6    Dra
# Found3    UMi
# FoundPHERKAD
# Found11    UMi
# FoundKOCHAB
# Found37    Dra
# Found31Psi1Dra
# Found34Psi2Dra
# Found43Phi Dra
# FoundALTAIS
# Found67Rho Dra
# Found61Sig Dra
# Found63Eps Dra
# Found63Eps Dra
# FoundAF DRA
# FoundALFIRK
# Found16    Cep
# Found34Omi Cep
# Found34Omi Cep
# Found49    Cas
# Found47    Cas
# Found15The UMi
# Found20    UMi
# Found41    Dra
# Found40    Dra
# Found59    Dra
# Found69    Dra
# Found75    Dra
# Found74    Dra
# Found33Pi  Cep
# FoundERRAI
# Found28Rho1Cep
# FoundPOLARIS
# FoundV CEP
# Found24    UMi
# Found10    Cet
# Found29    Psc
# Found14    Cet
# Found13    Cet
# Found13    Cet
# Found38    Cet
# Found34    Cet
# Found39    Cet
# Found43    Cet
# Found42    Cet
# Found42    Cet
# Found25    Cet
# Found61    Cet
# Found63    Cet
# Found66    Cet
# Found70    Cet
# Found68Omi Cet
# Found71    Cet
# Found75    Cet
# Found84    Cet
# Found84    Cet
# Found5    Eri
# Found81    Cet
# Found95    Cet
# Found95    Cet
# Found7    Eri
# Found25    Eri
# Found32    Eri
# Found32    Eri
# Found21    Eri
# Found22    Eri
# Found30    Eri
# FoundBEID
# Found37    Eri
# Found45    Eri
# Found51    Eri
# Found62    Eri
# Found61Ome Eri
# Found46    Eri
# Found46    Eri
# Found27    Ori
# Found31    Ori
# Found28Eta Ori
# Found28Eta Ori
# Found66    Eri
# Found68    Eri
# FoundCURSA
# Found65Psi Eri
# Found34Del Ori
# FoundMINTAKA
# FoundALNILAM
# Found50Zet Ori
# Found50Zet Ori
# Found48Sig Ori
# Found42    Ori
# Found45    Ori
# Found41The1Ori
# Found41The1Ori
# Found43The2Ori
# Found41The1Ori
# Found41The1Ori
# Found36Ups Ori
# Found49    Ori
# Found5Gam Mon
# Found11Bet Mon
# Found11Bet Mon
# Found11Bet Mon
# Found21    Mon
# Found24    Mon
# Found19    Mon
# Found28    Mon
# Found29Zet Mon
# Found1    Hya
# Found2    Hya
# Found15    Hya
# Found15    Hya
# Found31Tau1Hya
# Found21    Hya
# Found23    Hya
# Found32Tau2Hya
# Found33    Hya
# Found15Alp Sex
# Found30Bet Sex
# Found40    Sex
# Found40    Sex
# Found62    Leo
# Found61    Leo
# Found69    Leo
# Found87    Leo
# FoundZANIAH
# Found13    Vir
# Found29Gam Vir
# Found29Gam Vir
# Found38    Vir
# Found46    Vir
# Found48    Vir
# Found65    Vir
# Found66    Vir
# Found90    Vir
# Found74    Vir
# Found72    Vir
# Found102Ups Vir
# FoundSYRMA
# Found104    Vir
# Found106    Vir
# Found11    Lib
# Found16    Lib
# Found14    Ser
# Found11    Ser
# Found25    Ser
# Found36    Ser
# FoundYED PRIOR
# FoundYED POSTERIOR
# Found23    Oph
# Found41    Oph
# Found57Zet Ser
# Found61    Ser
# Found5    Aql
# Found8    Aql
# FoundEta Sct
# Found27    Aql
# Found14    Aql
# Found15    Aql
# Found26    Aql
# Found12    Aql
# Found41Iot Aql
# Found45    Aql
# Found42    Aql
# Found62    Aql
# Found64    Aql
# Found66    Aql
# Found68    Aql
# Found71    Aql
# Found70    Aql
# Found5    Aqr
# Found4    Aqr
# Found20    Aqr
# Found21    Aqr
# Found15    Aqr
# Found16    Aqr
# Found12    Aqr
# Found12    Aqr
# FoundSADALSUUD
# FoundSADALMELIK
# Found32    Aqr
# Found31Omi Aqr
# Found55Zet1Aqr
# Found55Zet1Aqr
# FoundSADACHBIA
# Found51    Aqr
# Found30    Aqr
# Found44    Aqr
# Found60    Aqr
# Found67    Aqr
# Found78    Aqr
# Found82    Aqr
# Found81    Aqr
# Found96    Aqr
# Found13    Psc
# Found14    Psc
# Found24    Psc
# Found3    Cet
# Found9    Cet
# Found17Phi1Cet
# Found21    Cet
# Found18    Cet
# Found22Phi3Cet
# Found23Phi4Cet
# Found27    Cet
# Found37    Cet
# Found32    Cet
# Found30    Cet
# Found28    Cet
# Found44    Cet
# Found46    Cet
# FoundBATEN KAITOS
# Found77    Cet
# Found8Rho1Eri
# Found9Rho2Eri
# FoundAZHA
# Found83Eps Cet
# Found10Rho3Eri
# Found14    Eri
# Found26Pi  Eri
# FoundZAURAK
# Found40Omi2Eri
# Found47    Eri
# Found39    Eri
# Found55    Eri
# Found55    Eri
# Found63    Eri
# Found64    Eri
# FoundRIGEL
# Found29    Ori
# Found3Iot Lep
# Found4Kap Lep
# Found4Kap Lep
# Found7Nu  Lep
# Found8    Lep
# Found55    Ori
# FoundSAIPH
# Found1    Mon
# Found2    Mon
# Found3    Mon
# Found3    Mon
# Found18The Lep
# Found6    Mon
# Found11    CMa
# Found18Mu  CMa
# Found5    Pup
# Found5    Pup
# Found8    Pup
# Found2    Pup
# Found2    Pup
# Found10    Pup
# Found9    Pup
# Found3    Hya
# Found19    Pup
# Found22    Pup
# Found18    Pup
# Found17    Hya
# Found17    Hya
# Found19    Hya
# Found19    Hya
# Found20    Hya
# Found12    Hya
# Found24    Hya
# FoundALPHARD
# Found29    Hya
# Found29    Hya
# Found27    Hya
# Found34    Hya
# Found37    Hya
# Found26    Hya
# Found8Gam Sex
# Found17    Sex
# Found18    Sex
# Found39Ups1Hya
# Found16Kap Crt
# Found14Eps Crt
# Found24Iot Crt
# Found21    Vir
# Found50    Vir
# Found49    Vir
# FoundSPICA
# Found76    Vir
# Found86    Vir
# Found86    Vir
# Found95    Vir
# Found96    Vir
# Found18    Lib
# Found17    Lib
# FoundZUBENESCHAMALI
# Found13Xi 1Lib
# Found7Mu  Lib
# Found7Mu  Lib
# Found31Eps Lib
# Found16    Sco
# Found18    Sco
# Found15Psi Sco
# FoundXi  Sco
# Found11    Sco
# Found11    Sco
# Found17Chi Sco
# Found3Ups Oph
# Found53Nu  Ser
# Found57Mu  Oph
# Found56Omi Ser
# Found69Tau Oph
# Found69Tau Oph
# FoundZet Sct
# Found56    Aql
# Found57    Aql
# Found57    Aql
# Found37    Aql
# Found65    Sgr
# Found1Xi 1Cap
# Found3    Cap
# Found2Xi 2Cap
# FoundALGEDI
# Found8Nu  Cap
# Found63    Sgr
# FoundDABIH
# FoundALBALI
# Found14Tau Cap
# Found17    Aqr
# Found7    Aqr
# Found19    Aqr
# Found46    Cap
# Found47    Cap
# Found42    Cap
# Found44    Cap
# Found45    Cap
# FoundANCHA
# Found46Rho Aqr
# Found38    Aqr
# Found39    Aqr
# Found42    Aqr
# Found50    Aqr
# Found45    Aqr
# Found58    Aqr
# Found70    Aqr
# Found74    Aqr
# Found56    Aqr
# Found69Tau1Aqr
# Found83    Aqr
# Found92Chi Aqr
# Found93Psi2Aqr
# Found94    Aqr
# Found102Ome1Aqr
# Found6    Cet
# Found7    Cet
# FoundDIPHDA; DENEB KAITOS
# Found49    Cet
# Found50    Cet
# Found57    Cet
# Found1Tau1Eri
# Found16Tau4Eri
# Found58    Eri
# Found54    Eri
# Found60    Eri
# Found59    Eri
# FoundARNEB
# FoundNIHAL
# Found10    Lep
# Found12    Lep
# Found17    Lep
# FoundMIRZAM
# Found19    Lep
# FoundSIRIUS
# Found6Nu 1CMa
# Found8Nu 3CMa
# Found8Nu 3CMa
# Found7Nu 2CMa
# Found19Pi  CMa
# Found15    CMa
# Found17    CMa
# Found12    CMa
# Found20Iot CMa
# Found6    Pup
# Found21    Pup
# Found14    Pup
# Found16    Pup
# Found9    Hya
# FoundPhi2Hya
# FoundPhi3Hya
# FoundALKES
# FoundPsi Crt
# Found13Lam Crt
# FoundGIENAH
# Found8Eta Crv
# FoundALGORAB
# Found5Zet Crv
# Found53    Vir
# Found54    Vir
# Found57    Vir
# Found54    Vir
# Found55    Vir
# Found69    Vir
# Found75    Vir
# Found85    Vir
# Found63    Vir
# Found73    Vir
# Found87    Vir
# FoundCS VIRGO
# Found5    Lib
# FoundZUBENELGENUBI
# Found21Nu  Lib
# Found29Omi Lib
# Found26    Lib
# Found28    Lib
# Found25Iot2Lib
# Found33 G LIB
# Found34Zet3Lib
# Found35Zet4Lib
# Found44Eta Lib
# Found46The Lib
# Found41    Lib
# Found47    Lib
# Found8Phi Oph
# Found7Chi Oph
# Found8Bet2Sco
# FoundGRAFFIAS
# Found14Nu  Sco
# Found14Nu  Sco
# Found14Nu  Sco
# Found4Psi Oph
# Found9Ome1Sco
# Found10Ome2Sco
# Found29    Oph
# Found9Ome Oph
# Found35Eta Oph
# Found40Xi  Oph
# Found52    Oph
# Found16    Sgr
# Found21    Sgr
# Found21    Sgr
# Found15    Sgr
# Found14    Sgr
# Found29    Sgr
# Found28    Sgr
# Found33    Sgr
# Found36Xi 1Sgr
# Found39Omi Sgr
# Found45Rho2Sgr
# Found44Rho1Sgr
# Found50    Sgr
# Found57    Sgr
# Found11Rho Cap
# Found10Pi  Cap
# Found12Omi Cap
# Found12Omi Cap
# Found7Sig Cap
# Found17    Cap
# Found29    Cap
# Found19    Cap
# Found31    Cap
# Found30    Cap
# Found20    Cap
# Found22Eta Cap
# Found27    Cap
# Found25Chi Cap
# Found28Phi Cap
# FoundNASHIRA
# FoundDENEB ALGEDI
# Found37    Cap
# Found43Kap Cap
# Found39Eps Cap
# Found33    Cap
# Found35    Cap
# Found36    Cap
# Found29    Aqr
# Found29    Aqr
# Found35    Aqr
# Found41    Aqr
# Found41    Aqr
# Found53    Aqr
# Found53    Aqr
# FoundSKAT
# Found77    Aqr
# Found66    Aqr
# Found97    Aqr
# Found89    Aqr
# Found99    Aqr
# Found1    Cet
# Found104    Aqr
# Found103    Aqr
# Found107    Aqr
# Found107    Aqr
# Found108    Aqr
# Found101    Aqr
# Found100    Aqr
# FoundKap1Scl
# FoundZet Scl
# FoundIot Scl
# FoundTau Scl
# Found56    Cet
# FoundOme For
# FoundOme For
# FoundGam1For
# Found6    Eri
# Found4    Eri
# Found15    Eri
# FoundZet For
# FoundGam2For
# FoundEps For
# FoundAlp For
# FoundAlp For
# Found28Tau7Eri
# Found33Tau8Eri
# FoundSig For
# Found36Tau9Eri
# Found50Ups1Eri
# Found1    Lep
# FoundNu 1Col
# FoundNu 2Col
# Found4Xi 1CMa
# Found16Omi1CMa
# Found26    CMa
# Found27    CMa
# Found28Ome CMa
# FoundADHARA
# Found29    CMa
# Found30Tau CMa
# FoundOmi Pup
# FoundALUDRA
# Found1    Pup
# Found3    Pup
# Found11    Pup
# Found12    Pup
# FoundEta Pyx
# FoundDel Pyx
# FoundZet Pyx
# FoundKap Pyx
# FoundLam Pyx
# FoundChi2Hya
# Found3    Crv
# Found1Alp Crv
# Found6    Crv
# Found45Psi Hya
# Found50    Hya
# Found51    Hya
# Found4    Lib
# Found54    Hya
# Found54    Hya
# Found55    Hya
# Found12    Lib
# Found57    Hya
# Found58    Hya
# Found59    Hya
# Found60    Hya
# Found23    Lib
# Found36    Lib
# Found42    Lib
# Found2    Sco
# Found2    Sco
# Found1    Sco
# Found3    Sco
# Found4    Sco
# Found40Tau Lib
# Found5Rho Sco
# Found5Rho Oph
# Found5Rho Oph
# Found19Omi Sco
# Found22    Sco
# Found13    Sco
# FoundANTARES
# Found12    Sco
# Found12    Sco
# Found24    Oph
# Found39Omi Oph
# Found39Omi Oph
# Found25    Sco
# Found26    Oph
# Found36    Oph
# Found36    Oph
# Found51    Oph
# Found43    Oph
# Found4    Sgr
# Found9    Sgr
# Found7    Sgr
# Found11    Sgr
# FoundGam1Sgr
# FoundKAUS MEDIA
# Found24    Sgr
# Found25    Sgr
# Found26    Sgr
# Found35Nu 2Sgr
# Found32Nu 1Sgr
# FoundKAUS BOREALIS
# FoundNUNKI
# Found49Chi3Sgr
# Found42Psi Sgr
# Found47Chi1Sgr
# Found38Zet Sgr
# Found53    Sgr
# Found51    Sgr
# Found60    Sgr
# Found58Ome Sgr
# Found59    Sgr
# Found41    Cap
# Found8    PsA
# Found13    PsA
# Found12Eta PsA
# Found12Eta PsA
# Found49    Aqr
# FoundZet PsA
# Found21    PsA
# Found19    PsA
# Found86    Aqr
# FoundFOMALHAUT
# FoundEta Scl
# FoundPi  For
# FoundIot1For
# FoundIot2For
# FoundPhi For
# FoundLam2For
# FoundEta1For
# FoundEta3For
# FoundEta2For
# FoundChi2For
# FoundChi3For
# FoundChi1For
# FoundRho For
# FoundZet Cae
# Found41Ups4Eri
# FoundGam1Cae
# FoundGam1Cae
# FoundGam2Cae
# FoundSig Col
# FoundMu  Col
# FoundEps Col
# FoundPHACT
# FoundLam Col
# FoundWAZN
# FoundXi  Col
# FoundFURUD
# FoundDel Col
# FoundLam CMa
# FoundThe Col
# Found10    CMa
# FoundBet Pyx
# FoundZet2Ant
# FoundZet1Ant
# FoundZet1Ant
# FoundDel Ant
# FoundBet Hya
# Found4    Cen
# Found3    Cen
# Found3    Cen
# Found2    Cen
# FoundMENKENT
# Found2    Lup
# Found3Psi1Lup
# Found4Psi2Lup
# FoundXi 2Lup
# FoundXi 1Lup
# Found27    Sco
# FoundLESATH
# FoundSHAULA
# FoundG SCO
# FoundALNASL
# Found18    Sgr
# FoundKAUS AUSTRALIS
# FoundEps CrA
# FoundGam CrA
# FoundGam CrA
# FoundThe2Sgr
# FoundBet Mic
# FoundAlp Mic
# FoundDel Mic
# Found5    PsA
# Found10The PsA
# Found7    PsA
# Found15Tau PsA
# FoundUps PsA
# Found23Del PsA
# Found22Gam PsA
# Found22Gam PsA
# FoundANKAA
# FoundKap Phe
# FoundLam1Scl
# FoundXi  Scl
# FoundChi Phe
# FoundPsi For
# FoundACAMAR
# FoundThe2Eri
# Found82 G  ERIDANI
# FoundDel Hor
# FoundPi 2Col
# FoundPi 1Col
# FoundPsi Vel
# FoundNu  Cen
# FoundPhi Cen
# FoundUps1Cen
# FoundChi Cen
# FoundOmi Lup
# FoundUps Lup
# FoundGam Lup
# FoundOme Lup
# FoundEps Lup
# FoundEta Lup
# FoundLam Nor
# FoundMu  Nor
# FoundMu 2Sco
# FoundZet1Sco
# FoundZet2Sco
# FoundIot2Sco
# FoundKap2CrA
# FoundKap1CrA
# FoundLam CrA
# FoundBet CrA
# FoundMu  CrA
# FoundDel CrA
# FoundZet CrA
# FoundEta2CrA
# FoundRUKBAT
# FoundARKAB
# FoundBet2Sgr
# FoundKap2Sgr
# FoundNu  Mic
# FoundEta Mic
# FoundThe2Mic
# FoundXi  Gru
# FoundMu 1Gru
# FoundMu 2Gru
# FoundSig1Gru
# FoundSig2Gru
# FoundSig2Gru
# FoundDel2Gru
# FoundUps Gru
# FoundRho Gru
# FoundPhi Gru
# FoundThe Gru
# FoundThe Gru
# FoundTau Phe
# FoundLam2Phe
# FoundBet Phe
# FoundNu  Phe
# FoundRho Phe
# FoundIot Hor
# FoundEta1Pic
# FoundLam Pic
# FoundThe Pic
# FoundBet Pic
# FoundGam1Vel
# FoundMu  Vel
# FoundMu  Vel
# FoundTau Cen
# FoundGam Cen
# FoundRho Cen
# FoundXi 1Cen
# FoundUps2Cen
# FoundIot Lup
# FoundTau2Lup
# FoundSig Lup
# FoundRho Lup
# FoundLam Lup
# FoundPi  Lup
# FoundPi  Lup
# FoundNu 1Lup
# FoundNu 2Lup
# FoundMu  Lup
# FoundKap2Lup
# FoundThe Nor
# FoundEps Nor
# FoundEta Nor
# FoundGam1Nor
# Found1Sig Ara
# FoundIot Ara
# FoundLam Ara
# FoundKap Ara
# FoundDel2Tel
# FoundDel1Tel
# FoundZet Tel
# FoundKap Tel
# FoundRho Tel
# FoundZet Ind
# FoundIot Ind
# FoundAL NA'IR
# FoundPi 1Gru
# FoundPi 2Gru
# FoundTau3Gru
# FoundTau1Gru
# FoundThe Phe
# FoundThe Phe
# FoundSig Phe
# FoundXi  Phe
# FoundZet Phe
# FoundACHERNAR
# FoundEta Hor
# FoundEps Ret
# FoundIot Pic
# FoundIot Pic
# FoundKap Dor
# FoundKap Pic
# FoundLam Dor
# FoundCANOPUS
# FoundNu  Pic
# FoundMu  Pic
# FoundMu  Pic
# FoundDel Vel
# FoundAVIOR
# FoundASPIDISKE
# FoundEta Car
# FoundOmi1Cen
# FoundOmi2Cen
# FoundGam Cru
# FoundGACRUX
# FoundMu 2Cru
# FoundMu 1Cru
# FoundLam Cru
# FoundGam Cir
# FoundZet Nor
# FoundIot2Nor
# FoundIot1Nor
# FoundEps2Ara
# FoundPi  Ara
# FoundGam Ara
# FoundMu  Tel
# FoundEta Tel
# FoundPEACOCK
# FoundThe Ind
# FoundThe Ind
# FoundMu  Ind
# FoundPi  Ind
# FoundKap1Ind
# FoundKap2Ind
# FoundEta Gru
# FoundKap Gru
# FoundBet1Tuc
# FoundBet2Tuc
# FoundBet3Tuc
# FoundRho Tuc
# FoundNu  Hor
# FoundGam Hor
# FoundBet Hor
# FoundZet1Ret
# FoundZet2Ret
# FoundGam Ret
# FoundIot Ret
# FoundThe Ret
# FoundThe Ret
# FoundEta2Dor
# FoundEps Dor
# FoundEta1Dor
# Foundq CAR
# FoundUps Car
# FoundUps Car
# FoundEps Cru
# FoundThe2Cru
# FoundThe1Cru
# FoundACRUX
# FoundAlp2Cru
# FoundEta Cru
# FoundZet Cru
# FoundMu  Mus
# FoundIot Cru
# FoundKap Cru
# FoundThe Mus
# FoundThe Mus
# FoundAlp2Cen
# FoundRIGEL KENTAURUS
# FoundAlp Cir
# FoundDel Cir
# FoundThe Cir
# FoundEps Cir
# FoundEta Cir
# FoundZet Cir
# FoundIot TrA
# FoundThe TrA
# FoundIot Pav
# FoundPi  Pav
# FoundOme Pav
# FoundNu  Pav
# FoundThe Pav
# FoundKap Pav
# FoundMu 2Pav
# FoundMu 1Pav
# FoundPhi2Pav
# FoundRho Pav
# FoundPhi1Pav
# FoundUps Pav
# FoundNu  Tuc
# FoundDel Tuc
# FoundEta Tuc
# FoundPi  Tuc
# FoundLam1Tuc
# FoundKap Tuc
# FoundThe Tuc
# FoundPi 2Hyi
# FoundPi 1Hyi
# FoundZet Hyi
# FoundPi 1Dor
# FoundBet Men
# FoundLam Men
# FoundPi 2Dor
# FoundGam1Vol
# FoundEps Vol
# FoundEps Vol
# FoundThe Vol
# FoundMIAPLACIDUS
# FoundKap2Vol
# FoundKap1Vol
# FoundEta Vol
# FoundZet2Mus
# FoundZet1Mus
# FoundEps Mus
# FoundBet Mus
# FoundIot2Mus
# FoundIot1Mus
# FoundKap TrA
# FoundKap2Aps
# FoundEta1TrA
# FoundATRIA
# FoundZet Aps
# FoundTau Pav
# FoundSig Pav
# FoundNu  Ind
# FoundSig Hyi
# FoundTau2Hyi
# FoundTau1Hyi
# FoundGam3Oct
# FoundNu  Hyi
# FoundNu  Men
# FoundIot Men
# FoundKap Men
# FoundPi  Men
# FoundThe Men
# FoundEps Men
# FoundNu  Cha
# FoundAlp Cha
# FoundIot Cha
# FoundZet Cha
# FoundMu 2Cha
# FoundMu 1Cha
# FoundKap Cha
# FoundEps Cha
# FoundDel1Cha
# FoundEps Aps
# FoundEta Aps
# FoundPhi Oct
# FoundDel2Aps
# FoundBet Aps
# FoundMu 2Oct
# FoundMu 1Oct
# FoundPsi Oct
# FoundXi  Oct
# FoundGam2Oct
# FoundGam1Oct
# FoundPi 1Oct
# FoundPi 2Oct
# FoundDel Oct
# FoundOme Oct
# FoundLam Oct
# FoundLam Oct

# %% [markdown]
# We can now add methods for searching directly for stars by name or coordinates.

# %%
tycho = Table.read('../data/tyc.fits')

def clean_name(n) -> str:
    if n is np.ma.masked:
        return ''
    n = str(n)
    n = n.strip()
    return n.lower()

def search_by_name(n: str):
    n = clean_name(n)
    name_col = tycho['Name'].filled('')
    name_strings = np.array([clean_name(n) for n in name_col])

    results = tycho[name_strings == n]
    print(len(results))

    return results

def search_by_coordinate(ra: float, dec: float, radius: float = 0.1):
    ra = float(ra)
    dec = float(dec)
    radius = float(radius)

    # Convert radius from degrees to radians
    radius_rad = np.radians(radius)

    # Calculate the distance in degrees
    delta_ra = np.radians(tycho['RAdeg'] - ra)
    delta_dec = np.radians(tycho['DEdeg'] - dec)

    # Haversine formula to calculate distance
    a = (np.sin(delta_dec / 2) ** 2 +
         np.cos(np.radians(dec)) * np.cos(np.radians(tycho['DEdeg'])) *
         np.sin(delta_ra / 2) ** 2)
    c = 2 * np.arcsin(np.sqrt(a))

    # Distance in radians
    distance_rad = c

    # Filter results within the specified radius
    results = tycho[distance_rad <= radius_rad]
    
    return results

target = search_by_name("pleiades")
print(f"{target}")

near = search_by_coordinate(target['RAdeg'], target['DEdeg'])
print(near)
# Out:
# 1
# RAdeg DEdeg  TYC Vmag   Name
#  deg   deg       mag
# ----- ------ --- ---- --------
# 3.783 24.117  OC  1.2 Pleiades
#   RAdeg       DEdeg        TYC      Vmag   Name
#    deg         deg                  mag
# ---------- ----------- ------------ ---- --------
# 3.86066522 24.06974512 1730  1332 1 9.47       --
#      3.783      24.117           OC  1.2 Pleiades
# C:\Users\314ow\AppData\Local\Temp\ipykernel_28424\2143646842.py:21: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ra = float(ra)
# C:\Users\314ow\AppData\Local\Temp\ipykernel_28424\2143646842.py:22: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   dec = float(dec)

# %%
messier = pd.read_csv('./catalog/messier.csv')
ngc = pd.read_csv('./catalog/ngc.csv')

dsos = []

for m in messier.itertuples():
    name = m.comments
    if name is np.nan:
        name = f"M-{m.messier_id}"
    ra = m.ra
    dec = m.dec
    vmag = m.v_mag
    dso_type = m.type
    dsos.append((ra, dec, dso_type, vmag, name))

for n in ngc.itertuples():
    name = n.comments
    if name is np.nan:
        name = f"NGC-{n.ngc_id}"
    ra = n.ra
    dec = n.dec
    vmag = n.v_mag
    dso_type = m.type
    dsos.append((ra, dec, dso_type, vmag, name))

tycho = Table.read('../data/tyc.fits')
tycho = vstack([tycho, Table(rows=dsos, names=('RAdeg', 'DEdeg', 'TYC', 'Vmag', 'Name'))])
tycho.write('../data/tyc.fits', format='fits', overwrite=True)

# %%
tycho = Table.read('../data/tyc.fits')
mask = [len(t['TYC']) == 2 for t in tycho]
print(tycho[mask])
print(len(tycho[mask]))
# Out:
# RAdeg   DEdeg  TYC Vmag                        Name
#  deg     deg       mag
# ------ ------- --- ---- --------------------------------------------------
#  3.783  24.117  OC  1.2                                           Pleiades
#  8.667  19.667  OC  3.1 Beehive cluster.  358 stars approx. 500 ly distant
# 17.883 -34.793  OC  3.3                                                M-7
#    0.7  41.267  SG  3.4                                   Andromeda galaxy
#  5.583  -5.383  DN  4.0                                 Great Orion nebula
# 17.667 -32.253  OC  4.2                                  Butterfly cluster
#    7.6 -14.483  OC  4.4                                               M-47
#  6.767 -20.757  OC  4.5                                               M-41
#  18.28  -18.55  OC  4.5                                               M-24
#    ...     ... ...  ...                                                ...
#  17.36   75.85  PN   --                                             GALAXY
# 13.873  76.183  PN   --                                       UNIDENTIFIED
#  9.262  76.383  PN   --                                       UNIDENTIFIED
# 10.903  77.283  PN   --                                       UNIDENTIFIED
#  8.927  78.417  PN   --                                               STAR
#  14.18  78.633  PN   --                                       UNIDENTIFIED
# 14.468    78.9  PN   --                                  OPEN STAR CLUSTER
# 10.453   79.85  PN   --                                             GALAXY
# 15.512  82.467  PN   --                                             GALAXY
#  7.933  85.167  PN   --                                             GALAXY
# Length = 13333 rows
# 13333
